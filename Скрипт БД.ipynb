-- %% [markdown]
-- # [Пробный_Экзамен]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Пробный_Экзамен]    Script Date: 25.09.2025 12:38:41 ******/
CREATE DATABASE [Пробный_Экзамен]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Пробный_Экзамен', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS01\MSSQL\DATA\Пробный_Экзамен.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Пробный_Экзамен_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS01\MSSQL\DATA\Пробный_Экзамен_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [Пробный_Экзамен] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Пробный_Экзамен].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Пробный_Экзамен] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Пробный_Экзамен] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Пробный_Экзамен] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Пробный_Экзамен] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Пробный_Экзамен] SET ARITHABORT OFF 
GO
ALTER DATABASE [Пробный_Экзамен] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [Пробный_Экзамен] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Пробный_Экзамен] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Пробный_Экзамен] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Пробный_Экзамен] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Пробный_Экзамен] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Пробный_Экзамен] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Пробный_Экзамен] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Пробный_Экзамен] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Пробный_Экзамен] SET  DISABLE_BROKER 
GO
ALTER DATABASE [Пробный_Экзамен] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Пробный_Экзамен] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Пробный_Экзамен] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Пробный_Экзамен] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Пробный_Экзамен] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Пробный_Экзамен] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Пробный_Экзамен] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Пробный_Экзамен] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [Пробный_Экзамен] SET  MULTI_USER 
GO
ALTER DATABASE [Пробный_Экзамен] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Пробный_Экзамен] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Пробный_Экзамен] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Пробный_Экзамен] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Пробный_Экзамен] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Пробный_Экзамен] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [Пробный_Экзамен] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[ИсторияУслугПартнеров]

-- %%
USE [Пробный_Экзамен]
GO

-- %%
/****** Object:  Table [dbo].[ИсторияУслугПартнеров]    Script Date: 25.09.2025 12:38:41 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ИсторияУслугПартнеров](
	[ID_Записи] [int] IDENTITY(1,1) NOT NULL,
	[НаименованиеУслуги] [nvarchar](255) NOT NULL,
	[НаименованиеПартнера] [nvarchar](255) NOT NULL,
	[Количество] [int] NOT NULL,
	[ДатаВыполнения] [datetime2](7) NOT NULL,
	[ДатаСоздания] [datetime2](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_Записи] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Материалы]

-- %%
/****** Object:  Table [dbo].[Материалы]    Script Date: 25.09.2025 12:38:41 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Материалы](
	[ID_Материала] [int] IDENTITY(1,1) NOT NULL,
	[ТипМатериала] [nvarchar](100) NOT NULL,
	[Наименование] [nvarchar](255) NOT NULL,
	[ID_Поставщика] [int] NOT NULL,
	[КоличествоВУпаковке] [decimal](18, 3) NOT NULL,
	[ЕдиницаИзмерения] [nvarchar](20) NOT NULL,
	[Описание] [nvarchar](max) NULL,
	[URL_Изображения] [nvarchar](500) NULL,
	[СтоимостьЗаЕдиницу] [decimal](18, 2) NOT NULL,
	[МинимальныйЗапас] [decimal](18, 3) NOT NULL,
	[ТекущийЗапас] [decimal](18, 3) NOT NULL,
	[ДатаСоздания] [datetime2](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_Материала] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Партнёры]

-- %%
/****** Object:  Table [dbo].[Партнёры]    Script Date: 25.09.2025 12:38:41 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Партнёры](
	[ID_Партнёра] [int] IDENTITY(1,1) NOT NULL,
	[ТипПартнёра] [nvarchar](50) NOT NULL,
	[Наименование] [nvarchar](255) NOT NULL,
	[Руководитель] [nvarchar](255) NOT NULL,
	[Email] [nvarchar](100) NULL,
	[Телефон] [nvarchar](20) NOT NULL,
	[ЮридическийАдрес] [nvarchar](500) NOT NULL,
	[ИНН] [nvarchar](12) NOT NULL,
	[Рейтинг] [int] NULL,
	[ДатаСоздания] [datetime2](7) NULL,
 CONSTRAINT [PK__Партнёры__8F820D5569F21892] PRIMARY KEY CLUSTERED 
(
	[ID_Партнёра] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UQ__Партнёры__A93E12BD6763FD8C] UNIQUE NONCLUSTERED 
(
	[ИНН] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ПерерасходМатериалов]

-- %%
/****** Object:  Table [dbo].[ПерерасходМатериалов]    Script Date: 25.09.2025 12:38:41 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ПерерасходМатериалов](
	[ID_Перерасхода] [int] IDENTITY(1,1) NOT NULL,
	[ТипМатериала] [nvarchar](100) NOT NULL,
	[ПроцентПерерасхода] [decimal](5, 4) NOT NULL,
	[ДатаСоздания] [datetime2](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_Перерасхода] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[ТипМатериала] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Поставщики]

-- %%
/****** Object:  Table [dbo].[Поставщики]    Script Date: 25.09.2025 12:38:41 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Поставщики](
	[ID_Поставщика] [int] IDENTITY(1,1) NOT NULL,
	[ТипПоставщика] [nvarchar](50) NOT NULL,
	[Наименование] [nvarchar](255) NOT NULL,
	[ИНН] [nvarchar](12) NOT NULL,
	[ДатаСоздания] [datetime2](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_Поставщика] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[ИНН] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Сотрудники]

-- %%
/****** Object:  Table [dbo].[Сотрудники]    Script Date: 25.09.2025 12:38:41 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Сотрудники](
	[ID_Сотрудника] [int] IDENTITY(1,1) NOT NULL,
	[ФИО] [nvarchar](255) NOT NULL,
	[ДатаРождения] [date] NOT NULL,
	[ПаспортныеДанные] [nvarchar](255) NOT NULL,
	[БанковскиеРеквизиты] [nvarchar](255) NOT NULL,
	[Должность] [nvarchar](100) NOT NULL,
	[СостояниеЗдоровья] [nvarchar](255) NULL,
	[Активен] [bit] NULL,
	[ДатаСоздания] [datetime2](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_Сотрудника] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ТипыУслуг]

-- %%
/****** Object:  Table [dbo].[ТипыУслуг]    Script Date: 25.09.2025 12:38:41 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ТипыУслуг](
	[ТипУслуги] [nvarchar](50) NOT NULL,
	[КоэффициентСложности] [decimal](3, 1) NOT NULL,
	[ДатаСоздания] [datetime2](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[ТипУслуги] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Услуги]

-- %%
/****** Object:  Table [dbo].[Услуги]    Script Date: 25.09.2025 12:38:41 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Услуги](
	[ID_Услуги] [int] IDENTITY(1,1) NOT NULL,
	[ТипУслуги] [nvarchar](50) NOT NULL,
	[Наименование] [nvarchar](255) NOT NULL,
	[КодУслуги] [nvarchar](50) NOT NULL,
	[МинимальнаяСтоимостьДляПартнера] [decimal](18, 2) NOT NULL,
	[НормаВремениМинуты] [int] NOT NULL,
	[Себестоимость] [decimal](18, 2) NOT NULL,
	[Цех] [int] NOT NULL,
	[ТребуемоеКоличествоПерсонала] [int] NOT NULL,
	[ДатаСоздания] [datetime2](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_Услуги] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[КодУслуги] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__ИсторияУс__ДатаС__39237A9A]

-- %%
ALTER TABLE [dbo].[ИсторияУслугПартнеров] ADD  DEFAULT (getdate()) FOR [ДатаСоздания]
GO

-- %% [markdown]
-- # [DF__Материалы__Текущ__15DA3E5D]

-- %%
ALTER TABLE [dbo].[Материалы] ADD  DEFAULT ((0)) FOR [ТекущийЗапас]
GO

-- %% [markdown]
-- # [DF__Материалы__ДатаС__17C286CF]

-- %%
ALTER TABLE [dbo].[Материалы] ADD  DEFAULT (getdate()) FOR [ДатаСоздания]
GO

-- %% [markdown]
-- # [DF__Партнёры__Рейтин__22401542]

-- %%
ALTER TABLE [dbo].[Партнёры] ADD  CONSTRAINT [DF__Партнёры__Рейтин__22401542]  DEFAULT ((0.00)) FOR [Рейтинг]
GO

-- %% [markdown]
-- # [DF__Партнёры__ДатаСо__24285DB4]

-- %%
ALTER TABLE [dbo].[Партнёры] ADD  CONSTRAINT [DF__Партнёры__ДатаСо__24285DB4]  DEFAULT (getdate()) FOR [ДатаСоздания]
GO

-- %% [markdown]
-- # [DF__Перерасхо__ДатаС__1D7B6025]

-- %%
ALTER TABLE [dbo].[ПерерасходМатериалов] ADD  DEFAULT (getdate()) FOR [ДатаСоздания]
GO

-- %% [markdown]
-- # [DF__Поставщик__ДатаС__10216507]

-- %%
ALTER TABLE [dbo].[Поставщики] ADD  DEFAULT (getdate()) FOR [ДатаСоздания]
GO

-- %% [markdown]
-- # [DF__Сотрудник__Актив__345EC57D]

-- %%
ALTER TABLE [dbo].[Сотрудники] ADD  DEFAULT ((1)) FOR [Активен]
GO

-- %% [markdown]
-- # [DF__Сотрудник__ДатаС__3552E9B6]

-- %%
ALTER TABLE [dbo].[Сотрудники] ADD  DEFAULT (getdate()) FOR [ДатаСоздания]
GO

-- %% [markdown]
-- # [DF__ТипыУслуг__ДатаС__27F8EE98]

-- %%
ALTER TABLE [dbo].[ТипыУслуг] ADD  DEFAULT (getdate()) FOR [ДатаСоздания]
GO

-- %% [markdown]
-- # [DF__Услуги__ДатаСозд__41B8C09B]

-- %%
ALTER TABLE [dbo].[Услуги] ADD  DEFAULT (getdate()) FOR [ДатаСоздания]
GO

-- %% [markdown]
-- # [FK__Материалы__ID_По__18B6AB08]

-- %%
ALTER TABLE [dbo].[Материалы]  WITH CHECK ADD FOREIGN KEY([ID_Поставщика])
REFERENCES [dbo].[Поставщики] ([ID_Поставщика])
GO

-- %% [markdown]
-- # [FK__Услуги__ТипУслуг__42ACE4D4]

-- %%
ALTER TABLE [dbo].[Услуги]  WITH CHECK ADD FOREIGN KEY([ТипУслуги])
REFERENCES [dbo].[ТипыУслуг] ([ТипУслуги])
GO

-- %% [markdown]
-- # [CK__ИсторияУс__Колич__382F5661]

-- %%
ALTER TABLE [dbo].[ИсторияУслугПартнеров]  WITH CHECK ADD CHECK  (([Количество]>(0)))
GO

-- %% [markdown]
-- # [CK__Материалы__Едини__12FDD1B2]

-- %%
ALTER TABLE [dbo].[Материалы]  WITH CHECK ADD CHECK  (([ЕдиницаИзмерения]=N'штуки' OR [ЕдиницаИзмерения]=N'кг' OR [ЕдиницаИзмерения]=N'литры'))
GO

-- %% [markdown]
-- # [CK__Материалы__Миним__14E61A24]

-- %%
ALTER TABLE [dbo].[Материалы]  WITH CHECK ADD CHECK  (([МинимальныйЗапас]>=(0)))
GO

-- %% [markdown]
-- # [CK__Материалы__Стоим__13F1F5EB]

-- %%
ALTER TABLE [dbo].[Материалы]  WITH CHECK ADD CHECK  (([СтоимостьЗаЕдиницу]>=(0)))
GO

-- %% [markdown]
-- # [CK__Материалы__Текущ__16CE6296]

-- %%
ALTER TABLE [dbo].[Материалы]  WITH CHECK ADD CHECK  (([ТекущийЗапас]>=(0)))
GO

-- %% [markdown]
-- # [CK__Партнёры__Рейтин__2334397B]

-- %%
ALTER TABLE [dbo].[Партнёры]  WITH CHECK ADD  CONSTRAINT [CK__Партнёры__Рейтин__2334397B] CHECK  (([Рейтинг]>=(0) AND [Рейтинг]<=(10)))
GO
ALTER TABLE [dbo].[Партнёры] CHECK CONSTRAINT [CK__Партнёры__Рейтин__2334397B]
GO

-- %% [markdown]
-- # [CK__Партнёры__ТипПар__214BF109]

-- %%
ALTER TABLE [dbo].[Партнёры]  WITH CHECK ADD  CONSTRAINT [CK__Партнёры__ТипПар__214BF109] CHECK  (([ТипПартнёра]=N'ЗАО' OR [ТипПартнёра]=N'ООО' OR [ТипПартнёра]=N'ИП'))
GO
ALTER TABLE [dbo].[Партнёры] CHECK CONSTRAINT [CK__Партнёры__ТипПар__214BF109]
GO

-- %% [markdown]
-- # [CK__Перерасхо__Проце__1C873BEC]

-- %%
ALTER TABLE [dbo].[ПерерасходМатериалов]  WITH CHECK ADD CHECK  (([ПроцентПерерасхода]>=(0) AND [ПроцентПерерасхода]<=(1)))
GO

-- %% [markdown]
-- # [CK__Поставщик__ТипПо__0F2D40CE]

-- %%
ALTER TABLE [dbo].[Поставщики]  WITH CHECK ADD CHECK  (([ТипПоставщика]=N'оборудование' OR [ТипПоставщика]=N'упаковка' OR [ТипПоставщика]=N'химия'))
GO

-- %% [markdown]
-- # [CK__ТипыУслуг__Коэфф__2704CA5F]

-- %%
ALTER TABLE [dbo].[ТипыУслуг]  WITH CHECK ADD CHECK  (([КоэффициентСложности]>(0)))
GO

-- %% [markdown]
-- # [CK__Услуги__Минималь__3CF40B7E]

-- %%
ALTER TABLE [dbo].[Услуги]  WITH CHECK ADD CHECK  (([МинимальнаяСтоимостьДляПартнера]>=(0)))
GO

-- %% [markdown]
-- # [CK__Услуги__НормаВре__3DE82FB7]

-- %%
ALTER TABLE [dbo].[Услуги]  WITH CHECK ADD CHECK  (([НормаВремениМинуты]>(0)))
GO

-- %% [markdown]
-- # [CK__Услуги__Себестои__3EDC53F0]

-- %%
ALTER TABLE [dbo].[Услуги]  WITH CHECK ADD CHECK  (([Себестоимость]>=(0)))
GO

-- %% [markdown]
-- # [CK__Услуги__Требуемо__40C49C62]

-- %%
ALTER TABLE [dbo].[Услуги]  WITH CHECK ADD CHECK  (([ТребуемоеКоличествоПерсонала]>(0)))
GO

-- %% [markdown]
-- # [CK__Услуги__Цех__3FD07829]

-- %%
ALTER TABLE [dbo].[Услуги]  WITH CHECK ADD CHECK  (([Цех]>(0)))
GO

-- %% [markdown]
-- # [Пробный_Экзамен]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Пробный_Экзамен] SET  READ_WRITE 
GO
